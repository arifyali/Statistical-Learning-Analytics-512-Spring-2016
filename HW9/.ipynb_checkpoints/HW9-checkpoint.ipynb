# %% [markdown]
# #Analytics 512 Homework #9

# %% [markdown]
# Arif Ali
#
# 05/01/16

# %% [markdown]
# ##Exercise 10.7 #2

# %% [markdown]
# Please see the last page of the PDF

# %% [markdown]
# ##Exercise 10.7 #4

# %% [markdown]
# ###Part A

# %% [markdown]
# The maximal and minimal intercluster dissimilarities are unknown, so it can not be determined whether the fusion from complete linkage with be greater than the fusion from single or if the two are equal. If the maximal and minimal intercluster dissimilarities are equal to one another then the fusion would occur at the same point. Otherwise the higher point would occur from the the complete linkage.

# %% [markdown]
# ###Part B

# %% [markdown]
# Linkage does not affect individual observations because there is no way to compute a maximal and minimal intercluster with only one possible match so the height should be the same

# %% [markdown]
# ##Exercise 10.7 #9

# %%
library(ISLR)
attach(USArrests)
# Out:
# The following objects are masked from USArrests (pos = 3):
#
#     Assault, Murder, Rape, UrbanPop

# %% [markdown]
# ###Part A

# %%
part_a = hclust(dist(USArrests))
plot(part_a)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ###Part B

# %%
part_b = cutree(part_a,3)
states = names(part_b)
#Group 1
states[part_b==1]
#Group 2
states[part_b==2]
#Group 3
states[part_b==3]
# Out:
#  [1] "Alabama"        "Alaska"         "Arizona"        "California"
#  [5] "Delaware"       "Florida"        "Illinois"       "Louisiana"
#  [9] "Maryland"       "Michigan"       "Mississippi"    "Nevada"
# [13] "New Mexico"     "New York"       "North Carolina" "South Carolina"
#  [1] "Arkansas"      "Colorado"      "Georgia"       "Massachusetts"
#  [5] "Missouri"      "New Jersey"    "Oklahoma"      "Oregon"
#  [9] "Rhode Island"  "Tennessee"     "Texas"         "Virginia"
# [13] "Washington"    "Wyoming"
#  [1] "Connecticut"   "Hawaii"        "Idaho"         "Indiana"
#  [5] "Iowa"          "Kansas"        "Kentucky"      "Maine"
#  [9] "Minnesota"     "Montana"       "Nebraska"      "New Hampshire"
# [13] "North Dakota"  "Ohio"          "Pennsylvania"  "South Dakota"
# [17] "Utah"          "Vermont"       "West Virginia" "Wisconsin"

# %% [markdown]
# ###Part C

# %%
part_c = hclust(dist(scale(USArrests)))

# %%
plot(part_c)
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ###Part D

# %%
part_d = cutree(part_c,3)

# %%
table(part_d == part_b)
# Out:
# FALSE  TRUE
#    22    28

# %% [markdown]
# The one thing that initially stands out is Alaska. By scaling the data, Alaska seems to be significiantly further from any of the observations, which could indicate a very different rate of crime, which is something to be more concerned of as opposed to the whole numbers as crime rates are usually what most individuals are concerned about.
